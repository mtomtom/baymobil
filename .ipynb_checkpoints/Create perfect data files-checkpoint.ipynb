# %%
## Clean up the files
import pandas as pd

## Load in the files and rename the columns. Format: SNP eco1 eco2, transcript where eco1 = local tissue, and eco2 = distal
## tissue in relation to sampling

#snp_ref = pd.read_csv("snp_ref.csv")
clean_files_path = "clean_files/"

## If the directory exists, then remove it and replace it with an empty directory
import os
import shutil

if os.path.exists(clean_files_path) and os.path.isdir(clean_files_path):
    shutil.rmtree(clean_files_path)
    
os.mkdir(clean_files_path)

## Load in the data files. Format each one individually.
#df = pd.read_csv("Col_hom_root_thieme.txt", delimiter="/t")
## Homografts
df = pd.read_csv("Col.S_Col.R_Flower_EM_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Flower_EM_rep1.csv", index=False)

df = pd.read_csv("Col.S_Col.R_Flower_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Flower_EM_rep2.csv", index=False)

df = pd.read_csv("Col.S_Col.R_Root_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Root_EM_rep2.csv", index=False)

df = pd.read_csv("Col.S_Col.R_Rosette_EM_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Rosette_EM_rep1.csv", index=False)

df = pd.read_csv("Col.S_Col.R_Rosette_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Rosette_EM_rep2.csv", index=False)

df = pd.read_csv("Col.S_Col.R_Stem_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Stem_EM_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Col.R_Stem_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Col.R_Stem_EM_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Flower_EM_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Flower_EM_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Flower_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Flower_EM_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Root_EM_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Root_EM_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Root_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Root_EM_rep1a.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Rosette_EM_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Rosette_EM_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Rosette_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Rosette_EM_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Stem_EM_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Stem_EM_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Ler.R_Stem_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Ler.R_Stem_EM_rep2.csv", index=False)

# %%
## Format is root shoot

df = pd.read_csv("Col.S_Ler.R_Flower_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Flower_EM_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Flower_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Flower_YX_rep1.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Flower_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Flower_YX_rep2.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Flower_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Flower_YX_rep3.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Root_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Root_EM_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Root_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Root_YX_rep1.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Root_YX_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Root_YX_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Root_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Root_YX_rep2.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Root_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Root_YX_rep3.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Rosette_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Rosette_EM_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Rosette_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Rosette_YX_rep1.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Rosette_YX_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Rosette_YX_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Rosette_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Rosette_YX_rep2.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Rosette_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Rosette_YX_rep3.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Stem_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Stem_EM_rep1a.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Stem_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Stem_YX_rep1.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Stem_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Stem_YX_rep2.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_Stem_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_Stem_YX_rep3.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_StemLeaves_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_StemLeaves_YX_rep1.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_StemLeaves_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_StemLeaves_YX_rep2.csv", index=False)

df = pd.read_csv("Col.S_Ler.R_StemLeaves_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Col.S_Ler.R_StemLeaves_YX_rep3.csv", index=False)


df = pd.read_csv("Ler.S_Col.R_Flower_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Flower_EM_rep1a.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Flower_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Flower_EM_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Flower_EM_rep4.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Flower_EM_rep4.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Flower_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Flower_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Flower_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Flower_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Flower_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Flower_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_EM_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_EM_rep1a.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_EM_rep4.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_EM_rep4.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_YX_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_YX_rep1a.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_YX_rep2a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_YX_rep2a.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Root_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Root_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Rosette_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Rosette_EM_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Rosette_EM_rep4.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Rosette_EM_rep4.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Rosette_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Rosette_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Rosette_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Rosette_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Rosette_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Rosette_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Stem_EM_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Stem_EM_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Stem_EM_rep4.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Stem_EM_rep4.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Stem_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Stem_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Stem_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Stem_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_Stem_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_Stem_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_StemLeaves_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_StemLeaves_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_StemLeaves_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_StemLeaves_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_Col.R_StemLeaves_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_Col.R_StemLeaves_YX_rep3.csv", index=False)

#Question_Ler.S_Col.R_Root_EM_rep2.txt

# %%
import pandas as pd 

clean_files_path = "clean_files/"

## Methylation
df = pd.read_csv("dn.S_dn.R_Flower_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Flower_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Flower_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Flower_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Flower_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Flower_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Root_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Root_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Root_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Root_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Root_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Root_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Rosette_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Rosette_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Rosette_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Rosette_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Rosette_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Rosette_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Stem_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Stem_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Stem_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Stem_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_dn.R_Stem_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_dn.R_Stem_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Flower_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Flower_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Flower_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Flower_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Flower_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Flower_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Root_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Root_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Root_YX_rep1a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Root_YX_rep1a.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Root_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Root_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Root_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Root_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Rosette_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Rosette_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Rosette_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Rosette_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Rosette_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Rosette_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Stem_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Stem_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Stem_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Stem_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Stem_YX_rep2a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Stem_YX_rep2a.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_Stem_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_Stem_YX_rep3.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_StemLeaves_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_StemLeaves_YX_rep1.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_StemLeaves_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_StemLeaves_YX_rep2.csv", index=False)

df = pd.read_csv("dn.S_Ler.R_StemLeaves_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "dn.S_Ler.R_StemLeaves_YX_rep3.csv", index=False)



df = pd.read_csv("Ler.S_dn.R_Flower_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Flower_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Flower_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Flower_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Flower_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Flower_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Root_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Root_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Root_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Root_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Root_YX_rep2a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Root_YX_rep2a.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Root_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco1", "lerDepth": "eco2", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Root_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Rosette_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Rosette_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Rosette_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Rosette_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Rosette_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Rosette_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Stem_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Stem_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Stem_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Stem_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Stem_YX_rep2a.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Stem_YX_rep2a.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_Stem_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_Stem_YX_rep3.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_StemLeaves_YX_rep1.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_StemLeaves_YX_rep1.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_StemLeaves_YX_rep2.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_StemLeaves_YX_rep2.csv", index=False)

df = pd.read_csv("Ler.S_dn.R_StemLeaves_YX_rep3.txt", delimiter="\t")
df = df[["SNP","depth", "colDepth","lerDepth"]]
df = df.rename(columns={"colDepth": "eco2", "lerDepth": "eco1", "depth": "N"})
df.to_csv(clean_files_path + "Ler.S_dn.R_StemLeaves_YX_rep3.csv", index=False)

# %%
## Load in the reference file and add the transcripts IDs to our datafiles

snp_ref = pd.read_csv("snp_ref.csv")
path = "clean_files/"
from os import listdir
from os.path import isfile, join
myfiles = [f for f in listdir(path) if not f.startswith('.') and isfile(join(path, f))]

for thisfile in myfiles:
    df = pd.read_csv(path + thisfile, index_col = None)
    df = pd.merge(df, snp_ref,on="SNP")
    df = df.rename(columns={"transcripts": "ID"})
    df.to_csv(path + thisfile, index=False)
